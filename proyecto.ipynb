# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"ML_cars.csv")
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.iloc[0]
# Out:
# car_ID                               1
# symboling                            3
# CarName             alfa-romero giulia
# fueltype                           gas
# aspiration                         std
# doornumber                         two
# carbody                    convertible
# drivewheel                         rwd
# enginelocation                   front
# wheelbase                         88.6
# carlength                        168.8
# carwidth                          64.1
# carheight                         48.8
# curbweight                        2548
# enginetype                        dohc
# cylindernumber                    four
# enginesize                         130
# fuelsystem                        mpfi
# boreratio                         3.47
# stroke                            2.68
# compressionratio                   9.0
# horsepower                         111
# peakrpm                           5000
# citympg                             21
# ...

# %%
df.price.describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
sns.boxplot(df.price)
# Out:
# <Axes: ylabel='price'>

# %%
df["doornumber"].value_counts()
# Out:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64

# %%
df.doornumber = df.doornumber.map({"four":4, "two":2})
df.doornumber
# Out:
# 0      2
# 1      2
# 2      2
# 3      4
# 4      4
#       ..
# 200    4
# 201    4
# 202    4
# 203    4
# 204    4
# Name: doornumber, Length: 205, dtype: int64

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df['gama'] = np.where(df['price'] > 30000, 1, 0)

# %%
columns = ['symboling','fueltype', 'aspiration',
'doornumber', 'carlength', 'carwidth', 
'carheight', 'curbweight', 'enginetype', 
'cylindernumber', 'enginesize', 'fuelsystem', 
'horsepower', 'peakrpm', 'citympg', 'highwaympg','gama']

# %%
df = df[columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar el DataFrame para obtener subconjuntos de gama alta y baja
df_alta_gama = df[df['gama'] == True]
df_baja_gama = df[df['gama'] == False]

# Función para graficar características para gama alta y baja
def plot_feature_distribution(feature):
    plt.figure(figsize=(12, 6))
    
    # Histograma para gama alta
    plt.subplot(1, 2, 1)
    if feature in ['carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'horsepower', 'peakrpm']:
        sns.histplot(df_alta_gama[feature], bins=5, color='skyblue', kde=True)
    else:
        sns.countplot(x=feature, data=df_alta_gama, palette='Set1')
    plt.title(f'Distribución en Gama Alta - {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frecuencia')

    # Histograma para gama baja
    plt.subplot(1, 2, 2)
    if feature in ['carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'horsepower', 'peakrpm']:
        sns.histplot(df_baja_gama[feature], bins=5, color='lightcoral', kde=True)
    else:
        sns.countplot(x=feature, data=df_baja_gama, palette='Set2')
    plt.title(f'Distribución en Gama Baja - {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frecuencia')

    plt.tight_layout()
    plt.show()

# Iterar sobre las columnas y graficar la distribución para cada una
for column in columns[:-1]:  # Excluyendo la columna 'gama'
    plot_feature_distribution(column)
# Out:
# C:\Users\ZeeD\AppData\Local\Temp\ipykernel_4440\3810275160.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df_alta_gama, palette='Set1')
# C:\Users\ZeeD\AppData\Local\Temp\ipykernel_4440\3810275160.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df_baja_gama, palette='Set2')
# C:\Users\ZeeD\AppData\Local\Temp\ipykernel_4440\3810275160.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df_alta_gama, palette='Set1')
# ...

# %%
alta = df.query("gama==1")
baja = df.query("gama==0")
for column in df.columns:
    try:
        print(f"Columna: {column}")
        print(f"ALTA: {alta[column].value_counts()}")
        print(f"BAJA: {baja[column].value_counts()}")
        print()
    except:
        print(f"Columna {column} es de tipo numérico")
        print(f"ALTA: {alta[column].describe}")
        print(f"BAJA: {baja[column].describe}")
# Out:
# Columna: symboling
# ALTA: symboling
#  0    7
#  3    4
# -1    2
#  1    2
# Name: count, dtype: int64
# BAJA: symboling
#  0    60
#  1    52
#  2    32
#  3    23
# -1    20
# -2     3
# Name: count, dtype: int64
#
# Columna: fueltype
# ALTA: fueltype
# gas       14
# diesel     1
# Name: count, dtype: int64
# BAJA: fueltype
# gas       171
# diesel     19
# Name: count, dtype: int64
#
# Columna: aspiration
# ALTA: aspiration
# std      14
# turbo     1
# Name: count, dtype: int64
# BAJA: aspiration
# std      154
# turbo     36
# Name: count, dtype: int64
#
# Columna: doornumber
# ALTA: doornumber
# 2    8
# 4    7
# Name: count, dtype: int64
# BAJA: doornumber
# 4    108
# 2     82
# Name: count, dtype: int64
#
# Columna: carlength
# ALTA: carlength
# 168.9    3
# 199.6    2
# 202.6    2
# 189.0    1
# 193.8    1
# 197.0    1
# 191.7    1
# 180.3    1
# 208.1    1
# 199.2    1
# 175.7    1
# Name: count, dtype: int64
# BAJA: carlength
# 157.3    15
# 188.8    11
# 171.7     7
# ...
